# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Constraints:
#
# 2 <= nums.length <= 104
# -109 <= nums[i] <= 109
# -109 <= target <= 109
# Only one valid answer exists.
#
#
# Follow-up: Can you come up with an algorithm that is less than O(n2) time complexity?

# %%
# 첫 번째 코드
# Runtime : 5.01%
# Memory : 51.42%
# Complexity : O(N**2)
class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        for i, num in  enumerate(nums):
            for j, num2 in enumerate(nums):
                if i == j:
                    pass
                else:
                    if num + num2 == target:
                        return [i, j]
                    else:
                        pass

# 이중 for문으로 time compl 이 매우 안좋다.

# %%
# 두 번째
# Runtime : 9ms / 36.72%
# Memory : 19.04 MB / 10.50%

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        nums_sum = sum(nums)
        nums_dict = {value:idx for idx, value in enumerate(nums)}
        print(nums_dict)
        for i, x in enumerate(nums):
            remain = target - x
            if remain in nums_dict:
                if i != int(nums_dict[remain]):
                    return [i, int(nums_dict[remain])]
                else:
                    pass
            else:
                pass

# dictionary 에서 key를 찾거나 와 set에서 값을 찾을 때에는 시간 복잡도가 O(1) 이다.
# 리스트를 순환하는 것은 O(N) 이므로 상대적으로 dict, set을 찾는게 시간적으로 유리하다.
# 우려했던 게 같은 수가 있으면 dict 에서 누락될거다 였는데
# 그런 우려는 안해도 됨 -> 답은 한 쌍밖에 없고, 같은 수가 정답이면 한 쌍밖에 없으므로, 리스트를 돌면서 어떻게든 만남

# 복잡도
# (1) 시간 복잡도
# - nums_sum = sum(nums) : O(n). 리스트의 모든 요소를 순회함.
# - nums_dict = {value : idx for idx, value in enumerate(nums)} : O(n). 리스트를 순회하면서 딕셔너리를 만들기 때문
# - for : O(n). 리스트를 순회함
# - if remain in nums_dict : O(1). 딕셔너리 키값 찾는 것은 O(1)
# - 따라서 O(n) + O(n) + O(n) + O(1) = O(n)

# %%
# 세 번째
# Runtime : 0ms / 100%
# Memory : 18.84 MB / 21.61%

class Solution:
    def twoSum(self, nums: List[int], target: int) -> List[int]:
        nums_dict = dict()
        for i, x in enumerate(nums):
            remain = target - x
            if remain in nums_dict:
                if i != int(nums_dict[remain]):
                    return [i, int(nums_dict[remain])]
                else:
                    nums_dict[x] = i
            else:
                nums_dict[x] = i

# 불필요한 함수 nums_sum 제거
# dict를 미리 선언하는 구문 제거 -> for문에서 하나씩 처리
# 더 이상 개선이 가능할까..?
