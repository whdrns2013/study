# %%
from typing import TypedDict

class Human(TypedDict):
    name: str
    age: int
    hobby: list[str]

h = Human()
h["name"] = "John Doe"
h["age"] = 50
h["hobby"] = ["Piano", "Tennis"]

# %%
from typing import TypedDict

class Human(TypedDict):
    name: str
    age: int
    hobby: list[str]

h: Human = {
    "name" : "John Doe",
    "age" : 50,
    "hobby" : ["Piano", "Tennis"]
}

# %%
from typing import TypedDict

class Human(TypedDict):
    name: str
    age: int
    hobby: list[str]

h = Human({"name":"John Doe", "age":50, "hobby":["Piano", "Tennis"]})

# %%
from typing import TypedDict

class Human(TypedDict):
    name: str
    age: int
    hobby: list[str]

h = Human(name="John Doe", "age"=50, "hobby"=["Piano", "Tennis"])
# Out:
#   Cell In[11], line 8
#     h = Human(name="John Doe", "age"=50, "hobby"=["Piano", "Tennis"])
#                                ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
from typing import TypedDict

class Human(TypedDict, total):
    name: str
    age: int
    hobby: list[str]

h = Human({"name":"John Doe", "age":50, "hobby":["Piano", "Tennis"]})
