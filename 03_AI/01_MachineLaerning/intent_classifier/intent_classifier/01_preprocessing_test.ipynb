# %%
import os
# import sys
# sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from core.settings import settings
from engine.data_handler import TrainDataHandler
from utils.text_normalizer import *

# %%
# train data prepare
origin_data_path = os.path.join(settings.DIRPATH.DATA_PATH, settings.DATA.ORIGIN_DATA)
data_handler = TrainDataHandler()
origin_data = data_handler.load_data(origin_data_path)
train_data = data_handler.preprocess(origin_data=origin_data)
data_handler.save_data(train_data, os.path.join(settings.DIRPATH.DATA_PATH, settings.DATA.TRAIN_DATA_FILE))
# Out:
# method : 1
# {0: <bound method Okt.nouns of <konlpy.tag._okt.Okt object at 0x10f4f8b30>>, 1: <bound method OktTokenizer._wrap_pos of <utils.tokenizer.OktTokenizer object at 0x10ef32960>>, 2: <bound method Okt.morphs of <konlpy.tag._okt.Okt object at 0x10f4f8b30>>, 3: <bound method Okt.phrases of <konlpy.tag._okt.Okt object at 0x10f4f8b30>>}
# <bound method OktTokenizer._wrap_pos of <utils.tokenizer.OktTokenizer object at 0x10ef32960>>
