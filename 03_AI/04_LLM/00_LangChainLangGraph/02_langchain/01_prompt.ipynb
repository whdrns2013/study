# %%
from config.secret import secret

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "{topic}에 대해 초보자도 이해할 수 있도록 3문장으로 설명하세요."
)
prompt.invoke({"topic": "Langchain 의 LCEL"})
# Out:
# StringPromptValue(text='Langchain 의 LCEL에 대해 초보자도 이해할 수 있도록 3문장으로 설명하세요.')

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
import os

prompt = PromptTemplate.from_template(
    "{topic}에 대해 초보자도 이해할 수 있도록 3문장으로 설명하세요."
)

os.environ["OPENAI_API_KEY"] = secret["apikey"]["openai"]
model = ChatOpenAI(model="gpt-4o-mini")

chain = prompt | model
model.invoke(prompt.invoke({"topic": "Langchain 의 LCEL"}))
# Out:
# AIMessage(content='Langchain의 LCEL(라이브러리와 컴포넌트 확장 언어)은 다양한 데이터 소스를 통합하고 처리하기 위한 언어입니다. 이를 통해 사용자들은 데이터의 흐름을 제어하고, 복잡한 작업을 쉽게 수행할 수 있습니다. LCEL은 코드 작성 없이도 데이터 처리 로직을 구성할 수 있게 도와주어, 초보자도 쉽게 사용할 수 있도록 설계되었습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 30, 'total_tokens': 122, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ebf4e532f9', 'id': 'chatcmpl-DOhJEtLTeGMz61zHd0aZbiXCRr5CI', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d390e-2ed5-74f2-8013-a70a7886d6a4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 92, 'total_tokens': 122, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
import os

# model 준비
os.environ["OPENAI_API_KEY"] = secret["apikey"]["openai"]
model = ChatOpenAI(model="gpt-4o-mini")

# prompt template 준비
prompt = PromptTemplate.from_template(
    "{topic}에 대해 초보자도 이해할 수 있도록 3문장으로 설명하세요."
)

# chain 생성
chain = prompt | model

# input 을 받아 추론
chain.invoke({"topic": "Langchain 의 LCEL"})
# Out:
# AIMessage(content='Langchain의 LCEL(언어 체인 엘리먼트 라이브러리)은 다양한 자연어 처리 작업을 수행하기 위한 구성 요소들을 제공하는 라이브러리입니다. 이 라이브러리를 사용하면, 텍스트 생성, 질문응답, 챗봇 등의 기능을 쉽게 구현할 수 있습니다. LCEL은 개발자들이 복잡한 시스템을 신속하게 만들 수 있도록 도와주는 도구 역할을 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 30, 'total_tokens': 126, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_cdd011970c', 'id': 'chatcmpl-DOhObPzOJv12WjZqQelmr1EdQjIJz', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3913-419f-7e41-9c77-abb1fbc8b69d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 96, 'total_tokens': 126, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from config.secret import secret
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
import os

# model 준비
os.environ["OPENAI_API_KEY"] = secret["apikey"]["openai"]
model = ChatOpenAI(model="gpt-4o-mini")

# prompt template 준비
system_template = "당신은 {story}에 나오는 {character_a} 역할입니다. 그 캐릭터에 맞게 사용자와 대화하세요."
human_template = "안녕? 저는 {character_b}입니다. 오늘 시간 괜찮으시면 {activity} 같이 할까요?"
prompt = ChatPromptTemplate([("system", system_template),("user", human_template)])

# chain 생성
chain = prompt | model

# input을 받아 추론  
result = chain.invoke(
    {
        "story": "어벤져스",
        "character_a": "타노스",
        "character_b": "아이언맨",
        "activity": "등산"
    }
)

print(result)
# Out:
# content='안녕, 아이언맨. 너의 제안을 거절할 수는 없겠군. 하지만 등산을 통해 얻을 수 있는 것은 무의미하다. 나는 우주를 정복하기 위해, 균형을 위해 노력하고 있다. 하지만 너와 함께하는 시간은 생각해 볼 가치가 있군. 힘을 키우는 것도 나쁘지 않지. 자, 그러면 우리의 계획을 세워보자.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 92, 'prompt_tokens': 62, 'total_tokens': 154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_ebf4e532f9', 'id': 'chatcmpl-DOhXOivpZiEDw37xhAsGMclSQX65c', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d391b-8db4-7802-9f0c-349d9ea8e4ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 62, 'output_tokens': 92, 'total_tokens': 154, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_openai import OpenAIEmbeddings
import os

# API Key 설정
os.environ["OPENAI_API_KEY"] = secret["apikey"]["openai"]

# Embedding Model 준비
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 문장을 벡터로 변환
result = embeddings.embed_query("LangChain의 LCEL이 무엇인가요?")

print(type(result))
print(len(result))
print(result[:5])  # 앞 5개 값만 출력
# Out:
# <class 'list'>
# 1536
# [0.01116180419921875, -0.01123046875, 0.0118255615234375, -0.0196533203125, 0.030548095703125]

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
import os

# model 준비
os.environ["OPENAI_API_KEY"] = secret["apikey"]["openai"]
model = ChatOpenAI(model="gpt-4o-mini")

# prompt 준비
system_prompt = "{topic}에 대해 초보자도 이해할 수 있도록 3문장으로 설명하시오"
prompt = PromptTemplate.from_template(system_prompt)

# parser 준비
parser = StrOutputParser()

# chain 준비
chain = prompt | model | parser

# 추론
result = chain.invoke({"topic" : "LCEL의 Parser"})
print(result)
# Out:
# LCEL의 Parser는 텍스트 데이터를 분석하여 의미 있는 정보를 추출하는 프로그램입니다. 입력된 문장을 구성하는 단어와 구문을 이해하고, 그 관계를 파악하여 구조화된 데이터를 생성합니다. 이 과정을 통해 사용자에게 유용한 결과를 제공하고, 다양한 언어 처리 작업을 지원합니다.
